# %% [markdown]
# <a href="https://colab.research.google.com/github/naponmeentah/my_project/blob/main/football/Football_stats_%5BAPI_Football%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## API-Football
# https://www.api-football.com/documentation-v3#section/Sample-Scripts/Python

# %%
# import libraries
import requests
import pandas as pd

# %% [markdown]
# ## Set Variables

# %%
# Set your API key
api_key = 'YOUR_API_KEY'

# %% [markdown]
# ## Test Get data

# %%
# set endpoint url
url = "https://v3.football.api-sports.io/leagues"

payload={}
headers = {
  'x-apisports-key': api_key,
}

# get data
response = requests.request("GET", url, headers=headers, data=payload)

# preview data in json
print(response.json())
# Out:
# {'get': 'leagues', 'parameters': [], 'errors': [], 'results': 1213, 'paging': {'current': 1, 'total': 1}, 'response': [{'league': {'id': 4, 'name': 'Euro Championship', 'type': 'Cup', 'logo': 'https://media.api-sports.io/football/leagues/4.png'}, 'country': {'name': 'World', 'code': None, 'flag': None}, 'seasons': [{'year': 2008, 'start': '2008-06-07', 'end': '2008-06-29', 'current': False, 'coverage': {'fixtures': {'events': True, 'lineups': True, 'statistics_fixtures': False, 'statistics_players': False}, 'standings': False, 'players': True, 'top_scorers': True, 'top_assists': True, 'top_cards': True, 'injuries': False, 'predictions': True, 'odds': False}}, {'year': 2012, 'start': '2012-06-08', 'end': '2012-07-01', 'current': False, 'coverage': {'fixtures': {'events': True, 'lineups': True, 'statistics_fixtures': False, 'statistics_players': False}, 'standings': False, 'players': True, 'top_scorers': True, 'top_assists': True, 'top_cards': True, 'injuries': False, 'predictions': True, 'odds': False}}, {'year': 2016, 'start': '2016-06-10', 'end': '2016-07-10', 'current': False, 'coverage': {'fixtures': {'events': True, 'lineups': True, 'statistics_fixtures': True, 'statistics_players': True}, 'standings': True, 'players': True, 'top_scorers': True, 'top_assists': True, 'top_cards': True, 'injuries': False, 'predictions': True, 'odds': False}}, {'year': 2020, 'start': '2019-03-21', 'end': '2021-07-11', 'current': False, 'coverage': {'fixtures': {'events': True, 'lineups': True, 'statistics_fixtures': True, 'statistics_players': True}, 'standings': True, 'players': True, 'top_scorers': True, 'top_assists': True, 'top_cards': True, 'injuries': False, 'predictions': True, 'odds': False}}, {'year': 2024, 'start': '2024-06-14', 'end': '2024-07-14', 'current': True, 'coverage': {'fixtures': {'events': True, 'lineups': True, 'statistics_fixtures': True, 'statistics_players': True}, 'standings': True, 'players': True, 'top_scorers': True, 'top_assists': True, 'top_cards': True, 'injuries': False, 'predictions': True, 'odds': False}}]}, {'league': {'id': 21, 'name': 'Confederations Cup', 'type': 'Cup', 'logo': 'https://media.api-sports.io/football/leagues/21.png'}, 'country': {'name': 'World', 'code': None, 'flag': None}, 'seasons': [{'year': 2009, 'start': '2009-06-14', 'end': '2009-06-28', 'current': False, 'coverage': {'fixtures': {'events': True, 'lineups': True, 'statistics_fixtures': False, 'statistics_players': False}, 'standings': False, 'players': True, 'top_scorers': True, 'top_assists': True, 'top_cards': True, 'injuries': False, 'predictions': True, 'odds': False}}, {'year': 2013, 'start': '2013-06-15', 'end': '2013-06-30', 'current': False, 'coverage': {'fixtures': {'events': True, 'lineups': True, 'statistics_fixtures': False, 'statistics_players': False}, 'standings': False, 'players': True, 'top_scorers': True, 'top_assists': True, 'top_cards': True, 'injuries': False, 'predictions': True, 'odds': False}}, {'year': 2017, 'start': '2017-06-17', 'end': '2017-07-02', 'current': True, 'coverage': {'fixtures': {'events': True, 'lineups': True, 'statistics_fixtures': True, 'statistics_players': False}, 'standings': False, 'players': True, 'top_scorers': True, 'top_assists': True, 'top_cards': True, 'injuries': False, 'predictions': True, 'odds': False}}]}, {'league': {'id': 62, 'name': 'Ligue 2', 'type': 'League', 'logo': 'https://media.api-sports.io/football/leagues/62.png'}, 'country': {'name': 'France', 'code': 'FR', 'flag': 'https://media.api-sports.io/flags/fr.svg'}, 'seasons': [{'year': 2010, 'start': '2010-08-06', 'end': '2011-05-20', 'current': False, 'coverage': {'fixtures': {'events': True, 'lineups': True, 'statistics_fixtures': False, 'statistics_players': False}, 'standings': True, 'players': True, 'top_scorers': True, 'top_assists': True, 'top_cards': True, 'injuries': False, 'predictions': True, 'odds': False}}, {'year': 2011, 'start': '2011-07-29', 'end': '2012-05-18', 'current': False, 'coverage': {'fixtures' ...

# %%
# check data type
type(response.json())
# Out:
# dict

# %% [markdown]
# ### Convert to Dataframe

# %%
# pandas dataframe
df = pd.DataFrame(response.json()['response'])
df.head()
# Out:
#                                               league  \
# 0  {'id': 4, 'name': 'Euro Championship', 'type':...
# 1  {'id': 21, 'name': 'Confederations Cup', 'type...
# 2  {'id': 62, 'name': 'Ligue 2', 'type': 'League'...
# 3  {'id': 61, 'name': 'Ligue 1', 'type': 'League'...
# 4  {'id': 144, 'name': 'Jupiler Pro League', 'typ...
#
#                                              country  \
# 0      {'name': 'World', 'code': None, 'flag': None}
# 1      {'name': 'World', 'code': None, 'flag': None}
# 2  {'name': 'France', 'code': 'FR', 'flag': 'http...
# 3  {'name': 'France', 'code': 'FR', 'flag': 'http...
# 4  {'name': 'Belgium', 'code': 'BE', 'flag': 'htt...
#
#                                              seasons
# 0  [{'year': 2008, 'start': '2008-06-07', 'end': ...
# 1  [{'year': 2009, 'start': '2009-06-14', 'end': ...
# 2  [{'year': 2010, 'start': '2010-08-06', 'end': ...
# 3  [{'year': 2010, 'start': '2010-08-07', 'end': ...
# 4  [{'year': 2010, 'start': '2010-07-30', 'end': ...

# %%
# 1. expand list using '.explode()' [list -> dict]
df_exploded = df.explode('seasons').reset_index(drop=True)

# 2. expand dict using 'pd.json_normalize()' [dict -> columns]
league_cols = pd.json_normalize(df_exploded['league']).add_prefix('league_')
country_cols = pd.json_normalize(df_exploded['country']).add_prefix('country_')
season_cols = pd.json_normalize(df_exploded['seasons']).add_prefix('season_')

# 3. Concatenate everything together
df_final = pd.concat([league_cols, country_cols, season_cols], axis=1)


print(df_final.columns)
df_final.head()
# Out:
# Index(['league_id', 'league_name', 'league_type', 'league_logo',
#        'country_name', 'country_code', 'country_flag', 'season_year',
#        'season_start', 'season_end', 'season_current',
#        'season_coverage.fixtures.events', 'season_coverage.fixtures.lineups',
#        'season_coverage.fixtures.statistics_fixtures',
#        'season_coverage.fixtures.statistics_players',
#        'season_coverage.standings', 'season_coverage.players',
#        'season_coverage.top_scorers', 'season_coverage.top_assists',
#        'season_coverage.top_cards', 'season_coverage.injuries',
#        'season_coverage.predictions', 'season_coverage.odds'],
#       dtype='object')
#    league_id        league_name league_type  \
# 0          4  Euro Championship         Cup
# 1          4  Euro Championship         Cup
# 2          4  Euro Championship         Cup
# 3          4  Euro Championship         Cup
# 4          4  Euro Championship         Cup
#
#                                          league_logo country_name  \
# 0  https://media.api-sports.io/football/leagues/4...        World
# 1  https://media.api-sports.io/football/leagues/4...        World
# 2  https://media.api-sports.io/football/leagues/4...        World
# 3  https://media.api-sports.io/football/leagues/4...        World
# 4  https://media.api-sports.io/football/leagues/4...        World
#
#   country_code country_flag  season_year season_start  season_end  ...  \
# 0         None         None         2008   2008-06-07  2008-06-29  ...
# 1         None         None         2012   2012-06-08  2012-07-01  ...
# 2         None         None         2016   2016-06-10  2016-07-10  ...
# 3         None         None         2020   2019-03-21  2021-07-11  ...
# 4         None         None         2024   2024-06-14  2024-07-14  ...
#
#    season_coverage.fixtures.statistics_fixtures  \
# 0                                         False
# 1                                         False
# 2                                          True
# 3                                          True
# 4                                          True
#
#    season_coverage.fixtures.statistics_players  season_coverage.standings  \
# 0                                        False                      False
# 1                                        False                      False
# 2                                         True                       True
# 3                                         True                       True
# 4                                         True                       True
#
#    season_coverage.players  season_coverage.top_scorers  \
# 0                     True                         True
# 1                     True                         True
# 2                     True                         True
# 3                     True                         True
# 4                     True                         True
#
#    season_coverage.top_assists  season_coverage.top_cards  \
# 0                         True                       True
# 1                         True                       True
# 2                         True                       True
# 3                         True                       True
# 4                         True                       True
#
#    season_coverage.injuries  season_coverage.predictions  season_coverage.odds
# 0                     False                         True                 False
# 1                     False                         True                 False
# 2                     False                         True                 False
# 3                     False                         True                 False
# 4                     False                         True                 False
#
# [5 rows x 23 columns]

# %% [markdown]
# # Players Stats

# %% [markdown]
# ## Get Player data
#
# 203224: Florian Wirtz
#
# 174565: Hugo Ekitike
#
# https://dashboard.api-football.com/soccer/ids/players

# %% [markdown]
# ### Test get data: Available seasons

# %%
# set endpoint url
url = "https://v3.football.api-sports.io/players/seasons?player=203224"

payload={}
headers = {
  'x-apisports-key': api_key,
}

# get data
response = requests.request("GET", url, headers=headers, data=payload)

# convert to dataframe
df_ss_wirtz = pd.DataFrame(response.json()['response']).rename(columns={0 : 'season'})
df_ss_wirtz.head()
# Out:
#    season
# 0    2010
# 1    2011
# 2    2012
# 3    2013
# 4    2014

# %% [markdown]
# ### Test get data: Player statistics

# %%
# set parameters
player_id = 203224
season = 2024

# set endpoint url
url = f"https://v3.football.api-sports.io/players?id={player_id}&season={season}"

payload={}
headers = {
  'x-apisports-key': api_key,
}

# get data
response = requests.request("GET", url, headers=headers, data=payload)

# convert to dataframe
df_wirtz = pd.DataFrame(response.json()['response'])
df_wirtz.head()
# Out:
#                                               player  \
# 0  {'id': 203224, 'name': 'F. Wirtz', 'firstname'...
#
#                                           statistics
# 0  [{'team': {'id': 168, 'name': 'Bayer Leverkuse...

# %%
# 1. expand list using '.explode()' [list -> dict]
df_exploded = df_wirtz.explode('statistics').reset_index(drop=True)

# 2. expand dict using 'pd.json_normalize()' [dict -> columns]
player_cols = pd.json_normalize(df_exploded['player']).add_prefix('player_')
stats_cols = pd.json_normalize(df_exploded['statistics']).add_prefix('stats_')

# 3. Concatenate everything together
df_wirtz_final = pd.concat([player_cols, stats_cols], axis=1)


print(df_wirtz_final.columns)
df_wirtz_final.head()
# Out:
# Index(['player_id', 'player_name', 'player_firstname', 'player_lastname',
#        'player_age', 'player_nationality', 'player_height', 'player_weight',
#        'player_injured', 'player_photo', 'player_birth.date',
#        'player_birth.place', 'player_birth.country', 'stats_team.id',
#        'stats_team.name', 'stats_team.logo', 'stats_league.id',
#        'stats_league.name', 'stats_league.country', 'stats_league.logo',
#        'stats_league.flag', 'stats_league.season', 'stats_games.appearences',
#        'stats_games.lineups', 'stats_games.minutes', 'stats_games.number',
#        'stats_games.position', 'stats_games.rating', 'stats_games.captain',
#        'stats_substitutes.in', 'stats_substitutes.out',
#        'stats_substitutes.bench', 'stats_shots.total', 'stats_shots.on',
#        'stats_goals.total', 'stats_goals.conceded', 'stats_goals.assists',
#        'stats_goals.saves', 'stats_passes.total', 'stats_passes.key',
#        'stats_passes.accuracy', 'stats_tackles.total', 'stats_tackles.blocks',
#        'stats_tackles.interceptions', 'stats_duels.total', 'stats_duels.won',
#        'stats_dribbles.attempts', 'stats_dribbles.success',
#        'stats_dribbles.past', 'stats_fouls.drawn', 'stats_fouls.committed',
#        'stats_cards.yellow', 'stats_cards.yellowred', 'stats_cards.red',
#        'stats_penalty.won', 'stats_penalty.commited', 'stats_penalty.scored',
#        'stats_penalty.missed', 'stats_penalty.saved'],
#       dtype='object')
#    player_id player_name player_firstname player_lastname  player_age  \
# 0     203224    F. Wirtz  Florian Richard           Wirtz          22
# 1     203224    F. Wirtz  Florian Richard           Wirtz          22
# 2     203224    F. Wirtz  Florian Richard           Wirtz          22
# 3     203224    F. Wirtz  Florian Richard           Wirtz          22
# 4     203224    F. Wirtz  Florian Richard           Wirtz          22
#
#   player_nationality player_height player_weight  player_injured  \
# 0            Germany           176            70           False
# 1            Germany           176            70           False
# 2            Germany           176            70           False
# 3            Germany           176            70           False
# 4            Germany           176            70           False
#
#                                         player_photo  ... stats_fouls.drawn  \
# 0  https://media.api-sports.io/football/players/2...  ...               8.0
# 1  https://media.api-sports.io/football/players/2...  ...               4.0
# 2  https://media.api-sports.io/football/players/2...  ...              39.0
# 3  https://media.api-sports.io/football/players/2...  ...               3.0
# 4  https://media.api-sports.io/football/players/2...  ...               8.0
#
#   stats_fouls.committed stats_cards.yellow  stats_cards.yellowred  \
# 0                     6                  2                    0.0
# 1                     4                  1                    NaN
# 2                    22                  3                    NaN
# 3                     1                  2                    NaN
# 4                     6                  2                    NaN
#
#   stats_cards.red stats_penalty.won  stats_penalty.commited  \
# 0               0              None                    None
# 1               0              None                    None
# 2               0              None                    None
# 3               0              None                    None
# 4               0              None                    None
#
#   stats_penalty.scored stats_penalty.missed stats_penalty.saved
# 0                    1                    0                None
# 1                    0                    0                None
# 2                    2                    2                None
# 3                    0                    0                None
# 4                    1                    0                None
#
# [5 rows x 59 columns]

# %% [markdown]
# ## Get Multiple Players Stats + All available seasons

# %%
# set players id
# 203224: Florian Wirtz
# 174565: Hugo Ekitike
# 2864: Alexander Isak
# 306: Mo Salah
# 2489: Luis Diaz
# 12339: Nunez

players_id = [203224, 174565, 2864, 306, 2489, 12339]
players_id
# Out:
# [203224, 174565, 2864, 306, 2489, 12339]

# %%
# set players id
players_id = [203224, 174565, 2864, 306, 2489, 12339]

# set empty data
all_data = []

# set API parameter
payload={}
headers = {'x-apisports-key': api_key,}

# Get data process
for player_id in players_id:

  url_ss = f"https://v3.football.api-sports.io/players/seasons?player={player_id}"

  response = requests.request("GET", url_ss, headers=headers, data=payload)

  # Check if 'response' key exists and is not empty
  if 'response' in response.json() and response.json()['response']:
      df_ss = pd.DataFrame(response.json()['response']).rename(columns={0 : 'season'})
  else:
      print(f"No seasons data found for player {player_id}")
      continue # Skip to the next player if no seasons data


  for season in df_ss['season']:
      url = f"https://v3.football.api-sports.io/players?id={player_id}&season={season}"


      response = requests.request("GET", url, headers=headers, data=payload)
      data_json = response.json()

      if data_json['response']:
          # 1. expand list using '.explode()' [list -> dict]
          df_exploded = pd.DataFrame(data_json['response']).explode('statistics').reset_index(drop=True)

          # 2. expand dict using 'pd.json_normalize()' [dict -> columns]
          player_cols = pd.json_normalize(df_exploded['player']).add_prefix('player_')
          stat_cols = pd.json_normalize(df_exploded['statistics']).add_prefix('stat_')

          # 3. Concatenate everything together
          df_season = pd.concat([player_cols, stat_cols], axis=1)
          all_data.append(df_season)
      else:
          print(f"No data for season {season} for player {player_id}")

# Filter out empty DataFrames before concatenation
all_data_filtered = [df for df in all_data if not df.empty]
df_final = pd.concat(all_data_filtered, ignore_index=True)

print(df_final.shape)
df_final.head()
# Out:
# No data for season 2019 for player 203224
# No data for season 2020 for player 203224
# No data for season 2021 for player 203224
# No data for season 2025 for player 203224
# No data for season 2019 for player 174565
# No data for season 2020 for player 174565
# No data for season 2021 for player 174565
# No data for season 2025 for player 174565
# No data for season 2015 for player 2864
# No data for season 2016 for player 2864
# No data for season 2017 for player 2864
# No data for season 2018 for player 2864
# No data for season 2019 for player 2864
# No data for season 2020 for player 2864
# No data for season 2021 for player 2864
# No data for season 2023 for player 2864
# No data for season 2024 for player 2864
# No data for season 2025 for player 2864
# No seasons data found for player 306
# No seasons data found for player 2489
# No seasons data found for player 12339
# (40, 59)
# /tmp/ipython-input-1057505069.py:49: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_final = pd.concat(all_data_filtered, ignore_index=True)
#    player_id player_name player_firstname player_lastname  player_age  \
# 0     203224    F. Wirtz  Florian Richard           Wirtz          22
# 1     203224    F. Wirtz  Florian Richard           Wirtz          22
# 2     203224    F. Wirtz  Florian Richard           Wirtz          22
# 3     203224    F. Wirtz  Florian Richard           Wirtz          22
# 4     203224    F. Wirtz  Florian Richard           Wirtz          22
#
#   player_nationality player_height player_weight  player_injured  \
# 0            Germany           176            70           False
# 1            Germany           176            70           False
# 2            Germany           176            70           False
# 3            Germany           176            70           False
# 4            Germany           176            70           False
#
#                                         player_photo  ... stat_fouls.drawn  \
# 0  https://media.api-sports.io/football/players/2...  ...             27.0
# 1  https://media.api-sports.io/football/players/2...  ...             10.0
# 2  https://media.api-sports.io/football/players/2...  ...              NaN
# 3  https://media.api-sports.io/football/players/2...  ...             27.0
# 4  https://media.api-sports.io/football/players/2...  ...              2.0
#
#   stat_fouls.committed stat_cards.yellow  stat_cards.yellowred stat_cards.red  \
# 0                 13.0                 4                   0.0              0
# 1                  4.0                 2                   0.0              0
# 2                  NaN                 0                   0.0              0
# 3                 23.0                 3                   0.0              0
# 4                  3.0                 0                   0.0              0
#
#   stat_penalty.won  stat_penalty.commited stat_penalty.scored  \
# 0             None                   None                 0.0
# 1             None                   None                 0.0
# 2             None                   None                 NaN
# 3             None                   None                 1.0
# 4             None                   None                 1.0
#
#   stat_penalty.missed stat_penalty.saved
# 0                 0.0               None
# 1                 0.0               None
# 2                 NaN               None
# 3                 0.0               None
# 4                 0.0               None
#
# [5 rows x 59 columns]

# %% [markdown]
# ## Export data to csv (save api quota)

# %%
# export to csv
df_final.to_csv('player_statistics.csv', index=False)
print("DataFrame 'df_final' successfully exported to 'player_statistics.csv'")
# Out:
# DataFrame 'df_final' successfully exported to 'player_statistics.csv'

# %% [markdown]
# ## Import csv data

# %%
# import csv
df_stats = pd.read_csv('player_statistics.csv')
df_stats.head()
# Out:
#    player_id player_name player_firstname player_lastname  player_age  \
# 0     203224    F. Wirtz  Florian Richard           Wirtz          22
# 1     203224    F. Wirtz  Florian Richard           Wirtz          22
# 2     203224    F. Wirtz  Florian Richard           Wirtz          22
# 3     203224    F. Wirtz  Florian Richard           Wirtz          22
# 4     203224    F. Wirtz  Florian Richard           Wirtz          22
#
#   player_nationality  player_height  player_weight  player_injured  \
# 0            Germany            176             70           False
# 1            Germany            176             70           False
# 2            Germany            176             70           False
# 3            Germany            176             70           False
# 4            Germany            176             70           False
#
#                                         player_photo  ... stat_fouls.drawn  \
# 0  https://media.api-sports.io/football/players/2...  ...             27.0
# 1  https://media.api-sports.io/football/players/2...  ...             10.0
# 2  https://media.api-sports.io/football/players/2...  ...              NaN
# 3  https://media.api-sports.io/football/players/2...  ...             27.0
# 4  https://media.api-sports.io/football/players/2...  ...              2.0
#
#   stat_fouls.committed stat_cards.yellow  stat_cards.yellowred stat_cards.red  \
# 0                 13.0                 4                   0.0              0
# 1                  4.0                 2                   0.0              0
# 2                  NaN                 0                   0.0              0
# 3                 23.0                 3                   0.0              0
# 4                  3.0                 0                   0.0              0
#
#   stat_penalty.won  stat_penalty.commited stat_penalty.scored  \
# 0              NaN                    NaN                 0.0
# 1              NaN                    NaN                 0.0
# 2              NaN                    NaN                 NaN
# 3              NaN                    NaN                 1.0
# 4              NaN                    NaN                 1.0
#
#   stat_penalty.missed stat_penalty.saved
# 0                 0.0                NaN
# 1                 0.0                NaN
# 2                 NaN                NaN
# 3                 0.0                NaN
# 4                 0.0                NaN
#
# [5 rows x 59 columns]

# %% [markdown]
# ## Prepare data

# %%
# select columns
df_prep = df_stats[['player_id', 'player_name', 'player_age', 'stat_team.id', 'stat_team.name', 'stat_league.id', 'stat_league.name','stat_league.season',
                    'stat_games.appearences', 'stat_games.lineups',
                    'stat_games.minutes', 'stat_games.number',
                    'stat_games.position', 'stat_games.rating', 'stat_substitutes.in',
                    'stat_substitutes.out', 'stat_substitutes.bench',
                    'stat_shots.total', 'stat_shots.on', 'stat_goals.total',
                    'stat_goals.conceded', 'stat_goals.assists', 'stat_passes.total',
                    'stat_passes.key', 'stat_passes.accuracy',
                    'stat_tackles.total', 'stat_tackles.blocks',
                    'stat_tackles.interceptions', 'stat_duels.total',
                    'stat_duels.won', 'stat_dribbles.attempts',
                    'stat_dribbles.success', 'stat_dribbles.past']]

# preview data
df_prep.head()
# Out:
#    player_id player_name  player_age  stat_team.id    stat_team.name  \
# 0     203224    F. Wirtz          22           168  Bayer Leverkusen
# 1     203224    F. Wirtz          22           168  Bayer Leverkusen
# 2     203224    F. Wirtz          22           168  Bayer Leverkusen
# 3     203224    F. Wirtz          22           168  Bayer Leverkusen
# 4     203224    F. Wirtz          22           168  Bayer Leverkusen
#
#    stat_league.id       stat_league.name  stat_league.season  \
# 0              78             Bundesliga                2022
# 1               3     UEFA Europa League                2022
# 2               2  UEFA Champions League                2022
# 3              78             Bundesliga                2023
# 4              81              DFB Pokal                2023
#
#    stat_games.appearences  stat_games.lineups  ...  stat_passes.key  \
# 0                      17                  11  ...             40.0
# 1                       8                   8  ...             25.0
# 2                       0                   0  ...              NaN
# 3                      32                  26  ...             74.0
# 4                       6                   5  ...             10.0
#
#    stat_passes.accuracy stat_tackles.total  stat_tackles.blocks  \
# 0                   NaN               18.0                  1.0
# 1                  52.0                7.0                  1.0
# 2                   NaN                NaN                  NaN
# 3                  46.0               28.0                  2.0
# 4                  42.0                4.0                  NaN
#
#    stat_tackles.interceptions  stat_duels.total  stat_duels.won  \
# 0                         1.0             190.0            95.0
# 1                         NaN              92.0            47.0
# 2                         NaN               NaN             NaN
# 3                         8.0             351.0           143.0
# 4                         1.0              54.0            21.0
#
#    stat_dribbles.attempts  stat_dribbles.success  stat_dribbles.past
# 0                    82.0                   48.0                 NaN
# 1                    44.0                   30.0                 NaN
# 2                     NaN                    NaN                 NaN
# 3                   153.0                   79.0                 NaN
# 4                    29.0                   14.0                 NaN
#
# [5 rows x 33 columns]

# %%
# summarize data
df_summarized = (df_prep

                 # group by data
                .groupby(['player_id', 'player_name', 'stat_league.season'])

                 # summarize data
                .agg(appearences=('stat_games.appearences', 'sum'),
                    line_up=('stat_games.lineups', 'sum'),
                    substitude=('stat_substitutes.in', 'sum'),
                    shots=('stat_shots.total', 'sum'),
                    goals=('stat_goals.total', 'sum'),
                    assists=('stat_goals.assists', 'sum'),
                    passes=('stat_passes.total', 'sum'),
                    key_passes=('stat_passes.key', 'sum'),
                    pass_acc=('stat_passes.accuracy', 'mean'),
                    duels=('stat_duels.total', 'sum'),
                    won_duels=('stat_duels.won', 'sum')
                    )

                  # calculate ratio
                 .assign(goal_per_app = lambda x: x['goals'] / x['appearences'] ,
                         ast_per_app = lambda x: x['assists'] / x['appearences'] ,
                         GA_per_app = lambda x: (x['goals'] + x['assists']) / x['appearences'])

                 # reset index
                 .reset_index()

                 # rename columns
                 .rename(columns={'stat_league.season' : 'season'})

)

# View data
df_summarized
# Out:
#    player_id player_name  season  appearences  line_up  substitude  shots  \
# 0       2864     A. Isak    2022           32       25           7   41.0
# 1     174565  H. Ekitike    2022           38       19          19   33.0
# 2     174565  H. Ekitike    2023           17        7          10   25.0
# 3     174565  H. Ekitike    2024           54       45           9  125.0
# 4     203224    F. Wirtz    2022           25       19           6   12.0
# 5     203224    F. Wirtz    2023           59       47          12   81.0
# 6     203224    F. Wirtz    2024           78       71           7  135.0
#
#    goals  assists  passes  key_passes  pass_acc  duels  won_duels  \
# 0   11.0      2.0   449.0        20.0       NaN  266.0      102.0
# 1    4.0      4.0   380.0        12.0       NaN  135.0       53.0
# 2    4.0      2.0   201.0        13.0       NaN  137.0       58.0
# 3   23.0     13.0   953.0        66.0       NaN  522.0      218.0
# 4    4.0      8.0  1080.0        65.0      52.0  282.0      142.0
# 5   18.0     20.0  2612.0       115.0      44.0  519.0      208.0
# 6   29.0     19.0  3576.0       164.0      44.0  774.0      328.0
#
#    goal_per_app  ast_per_app  GA_per_app
# 0      0.343750     0.062500    0.406250
# 1      0.105263     0.105263    0.210526
# 2      0.235294     0.117647    0.352941
# 3      0.425926     0.240741    0.666667
# 4      0.160000     0.320000    0.480000
# 5      0.305085     0.338983    0.644068
# 6      0.371795     0.243590    0.615385

# %%
# Export data
df_summarized.to_csv('player_stats_summary.csv', index=False)
